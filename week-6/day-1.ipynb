# %% [markdown]
# ## STATISTICS

# %%
import numpy as np
from scipy import stats

# %%
marks = [55, 60, 65, 70, 75, 80, 85, 90, 95]

# %%
print(f"mean : {np.mean(marks)}")
print(f"median : {np.median(marks)}")
print(f"mode : {stats.mode(marks)}")
print(f"variance : {np.var(marks)}")
print(f"standard deviation : {np.std(marks)}")
print(f"25th percentile : {np.percentile(marks,25)}")
print(f"50th percentile : {np.percentile(marks,50)}")
print(f"75th percentile : {np.percentile(marks,75)}")
# Out:
# mean : 75.0
# median : 75.0
# mode : ModeResult(mode=np.int64(55), count=np.int64(1))
# variance : 166.66666666666666
# standard deviation : 12.909944487358056
# 25th percentile : 65.0
# 50th percentile : 75.0
# 75th percentile : 85.0

# %%
marks = [55, 60, 65, 70, 75, 80, 85, 90, 95, 300] # outlier

# %%
print(f"mean : {np.mean(marks)}")
print(f"median : {np.median(marks)}")
print(f"mode : {stats.mode(marks)}")
print(f"variance : {np.var(marks)}")
print(f"standard deviation : {np.std(marks)}")
print(f"25th percentile : {np.percentile(marks,25)}")
print(f"50th percentile : {np.percentile(marks,50)}")
print(f"75th percentile : {np.percentile(marks,75)}")
# Out:
# mean : 97.5
# median : 77.5
# mode : ModeResult(mode=np.int64(55), count=np.int64(1))
# variance : 4706.25
# standard deviation : 68.60211367006121
# 25th percentile : 66.25
# 50th percentile : 77.5
# 75th percentile : 88.75
